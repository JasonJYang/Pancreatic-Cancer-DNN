# %% [markdown]
# # load data

# %%
import torch
import numpy as np
from data_loader.data_loaders import PCDataLoader
from model.model import MyDNN

# fix random seeds for reproducibility
SEED = 10
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

data_loader = PCDataLoader(model_dir='saved/models/DNN-NegativeSampling-NewDataT0.1/0801_222300/',
                           data_dir='data/',
                           batch_size=32,
                           group='PC',
                           seed=SEED,
                           shuffle=True,
                           validation_split=0.2,
                           test_split=0.0,
                           num_workers=2)

feature_list = data_loader.get_feature_list()

'''create dataframe'''
train_df = data_loader.df_train
valid_df = data_loader.df_valid

feature_num = data_loader.get_feature_num()

# build model architecture, then print to console
model = MyDNN(feature_num=feature_num,
              dropout=0.5)

# load trained model
resume_dir = 'saved/models/DNN-NegativeSampling-NewDataT0.1/0801_222300/model_best.pth'
checkpoint = torch.load(resume_dir,map_location ='cpu') #这里加了一句map_location ='cpu'
state_dict = checkpoint['state_dict']
model.load_state_dict(state_dict)

# prepare model for testing
device = torch.device('cpu')
model = model.to(device)
model.eval()

def df2tensor(df):
    tensor_df = torch.from_numpy(df.to_numpy())
    return tensor_df
# Out:
# Negative sampling...
# 107 positive and 107 negative records.
# 26 positive and 26 negative records.
# 23 positive and 23 negative records.

# %% [markdown]
# # select top patients

# %%
valid_df.head()
# Out:
#                NAME Group  Outcome  A_original_shape_VoxelVolume  \
# 102   PENG WANG XIN    PC        0                     -0.502184
# 12      DAI QUAN JU    PC        1                      0.264760
# 4    CHAI XIAO QING    PC        0                     -0.491792
# 14     FAN JIAN XIN    PC        0                     -0.550856
# 125    TIAN DE QING    PC        1                     -0.634819
#
#      A_original_shape_MeshVolume  A_original_shape_SurfaceArea  \
# 102                    -0.502126                     -0.611651
# 12                      0.263896                      0.800146
# 4                      -0.491558                     -0.586913
# 14                     -0.550588                     -0.726887
# 125                    -0.633989                     -0.978095
#
#      A_original_shape_SurfaceVolumeRatio  A_original_shape_Maximum3DDiameter  \
# 102                             0.647962                           -0.732197
# 12                             -0.589642                            1.496117
# 4                               0.590669                           -0.655520
# 14                              1.025006                           -0.836991
# 125                             2.462277                           -1.275515
#
#      A_original_shape_Maximum2DDiameterSlice  \
# 102                                -0.722840
# 12                                  1.525422
# 4                                  -0.438469
# 14                                 -0.867096
# 125                                -1.233172
#
#      A_original_shape_Maximum2DDiameterColumn  ...  \
# 102                                 -0.680767  ...
# 12                                   0.718595  ...
# 4                                   -0.590014  ...
# 14                                  -0.906961  ...
# 125                                 -1.304808  ...
#
#      P_wavelet-LLL_glrlm_LongRunEmphasis  \
# 102                            -0.524796
# 12                              0.537462
# 4                              -0.466472
# 14                             -0.598176
# 125                            -0.755795
#
#      P_wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis  \
# 102                                         -0.524836
# 12                                           0.537347
# 4                                           -0.466516
# 14                                          -0.598211
# 125                                         -0.755818
#
#      P_wavelet-LLL_glrlm_LongRunLowGrayLevelEmphasis  \
# 102                                        -0.524786
# 12                                          0.537490
# 4                                          -0.466462
# 14                                         -0.598168
# 125                                        -0.755789
#
#      P_wavelet-LLL_glrlm_RunEntropy  \
# 102                       -0.426402
# 12                         0.807331
# 4                         -0.406194
# 14                        -0.651449
# 125                       -1.511636
#
#      P_wavelet-LLL_glrlm_RunLengthNonUniformity  \
# 102                                   -0.307732
# 12                                     2.334529
# 4                                     -0.453249
# 14                                    -0.783742
# 125                                   -0.972166
#
#      P_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized  \
# 102                                           0.296657
# 12                                           -0.491107
# 4                                             0.272923
# 14                                            0.465321
# 125                                           1.564481
#
#      P_wavelet-LLL_glrlm_RunPercentage  P_wavelet-LLL_glrlm_RunVariance  \
# 102                           0.550718                        -0.498348
# 12                           -0.745436                         0.759380
# 4                             0.347249                        -0.508814
# 14                            0.518169                        -0.597798
# 125                           1.639152                        -0.792541
#
#      P_wavelet-LLL_glrlm_ShortRunEmphasis  \
# 102                              0.437964
# 12                               0.253348
# 4                                0.483275
# 14                               0.390699
# 125                              0.863647
#
#      P_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis
# 102                                          0.441617
# 12                                           0.257994
# 4                                            0.486685
# 14                                           0.394606
# 125                                          0.865010
#
# [5 rows x 618 columns]

# %%
import pandas as pd

result_df = pd.read_csv('saved/models/DNN-NegativeSampling-NewDataT0.1/0801_222300/valid_result.csv')
result_df.head()
# Out:
#    patient_index  prediction  true        patient
# 0             47    0.670299   0.0  PENG WANG XIN
# 1             41    0.387550   0.0    XV CHANG BI
# 2             22    0.438404   1.0  WU GUANG MING
# 3             44    0.503144   0.0   HE XIANG CUI
# 4             17    0.386973   0.0  GUAN ZHI QING

# %%
pos_df = result_df[result_df['true']==1]
pos_df = pos_df.sort_values(by=['prediction'], ascending=False)
pos_df.head()
# Out:
#     patient_index  prediction  true        patient
# 15             20    0.869387   1.0    ZHOU JIN JU
# 13             23    0.860005   1.0  ZHANG SAN MAO
# 26              9    0.858507   1.0   HUANG GAI DI
# 23             25    0.856949   1.0   LIU LA SHENG
# 28              6    0.806880   1.0      PAN ZI DA

# %%
neg_df = result_df[result_df['true']==0]
neg_df = neg_df.sort_values(by=['prediction'])
neg_df.head()
# Out:
#     patient_index  prediction  true        patient
# 14             27    0.163523   0.0     HU XI MING
# 6              51    0.280430   0.0  ZHOU QING YOU
# 12              5    0.281073   0.0     LIAO YI DE
# 4              17    0.386973   0.0  GUAN ZHI QING
# 1              41    0.387550   0.0    XV CHANG BI

# %%
valid_captum_df = pd.concat([pos_df.head(5), neg_df.head(5)])
valid_captum_df
# Out:
#     patient_index  prediction  true        patient
# 15             20    0.869387   1.0    ZHOU JIN JU
# 13             23    0.860005   1.0  ZHANG SAN MAO
# 26              9    0.858507   1.0   HUANG GAI DI
# 23             25    0.856949   1.0   LIU LA SHENG
# 28              6    0.806880   1.0      PAN ZI DA
# 14             27    0.163523   0.0     HU XI MING
# 6              51    0.280430   0.0  ZHOU QING YOU
# 12              5    0.281073   0.0     LIAO YI DE
# 4              17    0.386973   0.0  GUAN ZHI QING
# 1              41    0.387550   0.0    XV CHANG BI

# %%
feature_df = valid_df[valid_df['NAME'].isin(list(valid_captum_df['patient']))]
feature_df.drop_duplicates(subset=['NAME'], inplace=True)
feature_df
# Out:
# <ipython-input-11-c7efc50f5dc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_df.drop_duplicates(subset=['NAME'], inplace=True)
#               NAME Group  Outcome  A_original_shape_VoxelVolume  \
# 72      LIAO YI DE    PC        0                     -0.351118
# 98       PAN ZI DA    PC        1                     -0.170350
# 39    HUANG GAI DI    PC        1                      0.348478
# 210  ZHOU QING YOU    PC        0                     -0.550807
# 21   GUAN ZHI QING    PC        0                     -0.495371
# 208    ZHOU JIN JU    PC        1                     -0.365186
# 188  ZHANG SAN MAO    PC        1                     -0.073642
# 87    LIU LA SHENG    PC        1                      0.522090
# 37      HU XI MING    PC        0                     -0.647612
# 161    XV CHANG BI    PC        0                     -0.623987
#
#      A_original_shape_MeshVolume  A_original_shape_SurfaceArea  \
# 72                     -0.351256                      0.211344
# 98                     -0.170566                     -0.030491
# 39                      0.347708                      0.813244
# 210                    -0.550518                     -0.705309
# 21                     -0.495099                     -0.659872
# 208                    -0.365149                     -0.405409
# 188                    -0.073713                     -0.077649
# 87                      0.521425                      0.861888
# 37                     -0.646648                     -1.034104
# 161                    -0.623178                     -0.967422
#
#      A_original_shape_SurfaceVolumeRatio  A_original_shape_Maximum3DDiameter  \
# 72                              1.809260                            0.236758
# 98                             -0.420244                           -0.098230
# 39                             -0.764068                            1.017669
# 210                             1.221941                           -0.667503
# 21                              0.202229                           -0.769054
# 208                            -0.197797                           -0.085281
# 188                            -0.906574                            0.317927
# 87                             -1.027628                            0.476387
# 37                              2.742062                           -1.506360
# 161                             1.459340                           -1.234624
#
#      A_original_shape_Maximum2DDiameterSlice  \
# 72                                 -0.321728
# 98                                 -0.020091
# 39                                  0.866750
# 210                                -0.601907
# 21                                 -0.824317
# 208                                -0.239028
# 188                                -0.392229
# 87                                  0.607808
# 37                                 -1.435315
# 161                                -1.252729
#
#      A_original_shape_Maximum2DDiameterColumn  ...  \
# 72                                   0.168174  ...
# 98                                   0.075304  ...
# 39                                   1.435929  ...
# 210                                 -0.679314  ...
# 21                                  -0.727880  ...
# 208                                  0.069131  ...
# 188                                  0.466923  ...
# 87                                   0.851585  ...
# 37                                  -1.584747  ...
# 161                                 -1.463201  ...
#
#      P_wavelet-LLL_glrlm_LongRunEmphasis  \
# 72                             -0.823044
# 98                             -0.113896
# 39                              0.359791
# 210                            -0.602595
# 21                             -0.589246
# 208                             1.585890
# 188                             0.020108
# 87                              1.029156
# 37                             -0.827456
# 161                            -0.794333
#
#      P_wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis  \
# 72                                          -0.823063
# 98                                          -0.113965
# 39                                           0.359688
# 210                                         -0.602629
# 21                                          -0.589281
# 208                                          1.585700
# 188                                          0.020029
# 87                                           1.029005
# 37                                          -0.827475
# 161                                         -0.794353
#
#      P_wavelet-LLL_glrlm_LongRunLowGrayLevelEmphasis  \
# 72                                         -0.823040
# 98                                         -0.113879
# 39                                          0.359816
# 210                                        -0.602587
# 21                                         -0.589237
# 208                                         1.585936
# 188                                         0.020127
# 87                                          1.029192
# 37                                         -0.827452
# 161                                        -0.794328
#
#      P_wavelet-LLL_glrlm_RunEntropy  \
# 72                        -0.999603
# 98                        -0.111861
# 39                         0.664039
# 210                       -0.984234
# 21                        -0.637484
# 208                        1.656107
# 188                        0.750113
# 87                         1.305025
# 37                        -1.738300
# 161                       -1.337316
#
#      P_wavelet-LLL_glrlm_RunLengthNonUniformity  \
# 72                                     0.399108
# 98                                     0.290858
# 39                                     1.664224
# 210                                   -0.028853
# 21                                    -0.824912
# 208                                    0.586371
# 188                                   -0.316902
# 87                                     0.131601
# 37                                    -1.133850
# 161                                   -0.985566
#
#      P_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized  \
# 72                                            1.203848
# 98                                            0.222412
# 39                                           -0.415038
# 210                                           1.456128
# 21                                            0.286621
# 208                                          -1.464273
# 188                                          -1.094790
# 87                                           -1.395757
# 37                                            1.968106
# 161                                           1.533223
#
#      P_wavelet-LLL_glrlm_RunPercentage  P_wavelet-LLL_glrlm_RunVariance  \
# 72                            2.086140                        -0.696103
# 98                           -0.227451                        -0.206942
# 39                           -0.646333                         0.388575
# 210                           1.232567                        -0.646293
# 21                            0.359698                        -0.602873
# 208                          -1.506486                         1.675179
# 188                          -0.757075                         0.056450
# 87                           -1.341139                         0.998910
# 37                            1.964166                        -0.834454
# 161                           1.521211                        -0.750537
#
#      P_wavelet-LLL_glrlm_ShortRunEmphasis  \
# 72                               1.949288
# 98                               0.648873
# 39                               0.291812
# 210                              1.685187
# 21                              -0.354111
# 208                             -1.133086
# 188                             -1.530837
# 87                              -1.589062
# 37                               1.146278
# 161                              1.510615
#
#      P_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis
# 72                                           1.944810
# 98                                           0.651392
# 39                                           0.296252
# 210                                          1.682129
# 21                                          -0.346196
# 208                                         -1.120979
# 188                                         -1.516591
# 87                                          -1.574502
# 37                                           1.146120
# 161                                          1.508496
#
# [10 rows x 618 columns]

# %% [markdown]
# # captum

# %%
import torch
from captum.attr import IntegratedGradients
ig = IntegratedGradients(model)

test_feature = df2tensor(feature_df[feature_list])
ig_attr_test = ig.attribute(test_feature.float(), n_steps=10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py:202: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370172916/work/c10/cuda/CUDAFunctions.cpp:100.)
#   return Variable._execution_engine.run_backward(

# %%
ig_attr_test.shape
# Out:
# torch.Size([10, 615])

# %%
ig_attr_test_df = pd.DataFrame(ig_attr_test.cpu().detach().numpy(), columns=feature_list)
ig_attr_test_df.head()
# Out:
#    A_original_shape_VoxelVolume  A_original_shape_MeshVolume  \
# 0                     -0.000194                    -0.000288
# 1                     -0.000052                    -0.000112
# 2                      0.000172                     0.000305
# 3                     -0.000233                    -0.000270
# 4                     -0.000253                    -0.000291
#
#    A_original_shape_SurfaceArea  A_original_shape_SurfaceVolumeRatio  \
# 0                      0.000101                            -0.000383
# 1                      0.000161                            -0.000375
# 2                     -0.004244                            -0.000508
# 3                      0.000310                            -0.000143
# 4                     -0.000185                             0.000133
#
#    A_original_shape_Maximum3DDiameter  \
# 0                            0.000764
# 1                            0.000571
# 2                           -0.005510
# 3                           -0.002014
# 4                           -0.002507
#
#    A_original_shape_Maximum2DDiameterSlice  \
# 0                                -0.001766
# 1                                 0.000063
# 2                                -0.001982
# 3                                -0.004114
# 4                                -0.006637
#
#    A_original_shape_Maximum2DDiameterColumn  \
# 0                                  0.000507
# 1                                 -0.000508
# 2                                 -0.009382
# 3                                 -0.001664
# 4                                 -0.002562
#
#    A_original_shape_Maximum2DDiameterRow  A_original_shape_MajorAxisLength  \
# 0                               0.000238                          0.001271
# 1                              -0.000225                          0.001277
# 2                               0.002741                         -0.005888
# 3                              -0.000318                         -0.001489
# 4                              -0.002107                         -0.001759
#
#    A_original_shape_MinorAxisLength  ...  P_wavelet-LLL_glrlm_LongRunEmphasis  \
# 0                          0.000033  ...                            -0.000592
# 1                         -0.000132  ...                             0.000043
# 2                         -0.002670  ...                            -0.000098
# 3                          0.000808  ...                            -0.000266
# 4                          0.000423  ...                            -0.000572
#
#    P_wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis  \
# 0                                         -0.000279
# 1                                         -0.000019
# 2                                          0.000155
# 3                                          0.000021
# 4                                         -0.000386
#
#    P_wavelet-LLL_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                        -0.000296
# 1                                         0.000003
# 2                                         0.000093
# 3                                        -0.000038
# 4                                        -0.000335
#
#    P_wavelet-LLL_glrlm_RunEntropy  P_wavelet-LLL_glrlm_RunLengthNonUniformity  \
# 0                        0.000011                                   -0.000762
# 1                        0.000192                                    0.005709
# 2                       -0.001432                                    0.031348
# 3                        0.000197                                    0.000143
# 4                       -0.000024                                    0.000005
#
#    P_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized  \
# 0                                           0.000212
# 1                                           0.000390
# 2                                          -0.000820
# 3                                           0.000727
# 4                                           0.000068
#
#    P_wavelet-LLL_glrlm_RunPercentage  P_wavelet-LLL_glrlm_RunVariance  \
# 0                           0.000235                        -0.000241
# 1                          -0.000004                         0.000035
# 2                          -0.000246                        -0.000071
# 3                           0.000107                         0.000070
# 4                          -0.000010                        -0.000251
#
#    P_wavelet-LLL_glrlm_ShortRunEmphasis  \
# 0                             -0.011180
# 1                             -0.005947
# 2                             -0.002635
# 3                             -0.005168
# 4                              0.001364
#
#    P_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis
# 0                                         -0.007874
# 1                                         -0.004452
# 2                                         -0.002118
# 3                                         -0.009246
# 4                                          0.002820
#
# [5 rows x 615 columns]

# %%
print(len(ig_attr_test_df))
# Out:
# 10

# %%
valid_captum_df.reset_index(inplace=True, drop=True)
ig_attr_test_df = pd.concat([valid_captum_df, ig_attr_test_df], axis=1)
ig_attr_test_df.head()
# Out:
#    patient_index  prediction  true        patient  \
# 0             20    0.869387   1.0    ZHOU JIN JU
# 1             23    0.860005   1.0  ZHANG SAN MAO
# 2              9    0.858507   1.0   HUANG GAI DI
# 3             25    0.856949   1.0   LIU LA SHENG
# 4              6    0.806880   1.0      PAN ZI DA
#
#    A_original_shape_VoxelVolume  A_original_shape_MeshVolume  \
# 0                     -0.000194                    -0.000288
# 1                     -0.000052                    -0.000112
# 2                      0.000172                     0.000305
# 3                     -0.000233                    -0.000270
# 4                     -0.000253                    -0.000291
#
#    A_original_shape_SurfaceArea  A_original_shape_SurfaceVolumeRatio  \
# 0                      0.000101                            -0.000383
# 1                      0.000161                            -0.000375
# 2                     -0.004244                            -0.000508
# 3                      0.000310                            -0.000143
# 4                     -0.000185                             0.000133
#
#    A_original_shape_Maximum3DDiameter  \
# 0                            0.000764
# 1                            0.000571
# 2                           -0.005510
# 3                           -0.002014
# 4                           -0.002507
#
#    A_original_shape_Maximum2DDiameterSlice  ...  \
# 0                                -0.001766  ...
# 1                                 0.000063  ...
# 2                                -0.001982  ...
# 3                                -0.004114  ...
# 4                                -0.006637  ...
#
#    P_wavelet-LLL_glrlm_LongRunEmphasis  \
# 0                            -0.000592
# 1                             0.000043
# 2                            -0.000098
# 3                            -0.000266
# 4                            -0.000572
#
#    P_wavelet-LLL_glrlm_LongRunHighGrayLevelEmphasis  \
# 0                                         -0.000279
# 1                                         -0.000019
# 2                                          0.000155
# 3                                          0.000021
# 4                                         -0.000386
#
#    P_wavelet-LLL_glrlm_LongRunLowGrayLevelEmphasis  \
# 0                                        -0.000296
# 1                                         0.000003
# 2                                         0.000093
# 3                                        -0.000038
# 4                                        -0.000335
#
#    P_wavelet-LLL_glrlm_RunEntropy  P_wavelet-LLL_glrlm_RunLengthNonUniformity  \
# 0                        0.000011                                   -0.000762
# 1                        0.000192                                    0.005709
# 2                       -0.001432                                    0.031348
# 3                        0.000197                                    0.000143
# 4                       -0.000024                                    0.000005
#
#    P_wavelet-LLL_glrlm_RunLengthNonUniformityNormalized  \
# 0                                           0.000212
# 1                                           0.000390
# 2                                          -0.000820
# 3                                           0.000727
# 4                                           0.000068
#
#    P_wavelet-LLL_glrlm_RunPercentage  P_wavelet-LLL_glrlm_RunVariance  \
# 0                           0.000235                        -0.000241
# 1                          -0.000004                         0.000035
# 2                          -0.000246                        -0.000071
# 3                           0.000107                         0.000070
# 4                          -0.000010                        -0.000251
#
#    P_wavelet-LLL_glrlm_ShortRunEmphasis  \
# 0                             -0.011180
# 1                             -0.005947
# 2                             -0.002635
# 3                             -0.005168
# 4                              0.001364
#
#    P_wavelet-LLL_glrlm_ShortRunLowGrayLevelEmphasis
# 0                                         -0.007874
# 1                                         -0.004452
# 2                                         -0.002118
# 3                                         -0.009246
# 4                                          0.002820
#
# [5 rows x 619 columns]

# %%
ig_attr_test_df.to_csv('test_IntegratedGradients.csv', index=False)
